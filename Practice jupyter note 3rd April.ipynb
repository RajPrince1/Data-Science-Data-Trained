# %%
print ("Practice test")
print ("Date:03/04/2020")
print ("New file by kernel3 ipykernel practice")
print ("can edit in cell as well and click run to execute commands")
# Out:
# Practice test
# Date:03/04/2020
# New file by kernel3 ipykernel practice
# can edit in cell as well and click run to execute commands

# %%
print (" u can add cell by clicking symbol (+) and can cut cell by clicking symbol (scissor)")
# Out:
#  u can add cell by clicking symbol (+) and can cut cell by clicking symbol (scissor)

# %%
print ("go to file and download file and save as (notebook ipynb format) ")
# Out:
# go to file and download file and save as (notebook ipynb format)
